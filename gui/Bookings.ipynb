# %%
import pandas as pd
from matplotlib import pyplot as plt
import datetime
import pytz
import numpy as np

# %%
group1Participants = [10,11,12,13] 
startAnnotation = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
startCoordination = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))

bookings = pd.read_json("bookingsFINAL.json")

bookings = pd.DataFrame(bookings.fields.values.tolist())

bookings['start'] = pd.to_datetime(bookings['start'],infer_datetime_format=True)
bookings['created_at'] = pd.to_datetime(bookings['created_at'],infer_datetime_format=True)
bookings['modified_at'] = pd.to_datetime(bookings['modified_at'],infer_datetime_format=True)

bookings = bookings.loc[bookings['user'].isin(group1Participants)] 
bookings = bookings.loc[bookings['start']>= startCoordination ] 

bookings
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 startAnnotation = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
#       3 startCoordination = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))
# ----> 5 bookings = pd.read_json("bookingsFINAL.json")
#       7 bookings = pd.DataFrame(bookings.fields.values.tolist())
#       9 bookings['start'] = pd.to_datetime(bookings['start'],infer_datetime_format=True)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
import datetime
import pytz
import numpy as np

group1Participants = [10,11,12,13]
group2Participants = [15,16,17,18]
group3Participants = [19,20,21]
group4Participants = [24,25,28,29,30]

annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))

bookings = pd.read_json("../ec_data/all_bookings27-7-23.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 15
#      12 annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
#      13 coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))
# ---> 15 bookings = pd.read_json("../ec_data/all_bookings27-7-23.json")
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
import datetime
import pytz
import numpy as np

group1Participants = [10,11,12,13]
group2Participants = [15,16,17,18]
group3Participants = [19,20,21]
group4Participants = [24,25,28,29,30]

annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))

bookings = pd.read_json("all_bookings27-7-23.json", lines=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 15
#      12 annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
#      13 coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))
# ---> 15 bookings = pd.read_json("../ec_data/all_bookings27-7-23.json")
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
import datetime
import pytz
import numpy as np

group1Participants = [10,11,12,13]
group2Participants = [15,16,17,18]
group3Participants = [19,20,21]
group4Participants = [24,25,28,29,30]

annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))

bookings = pd.read_json("all_bookings27-7-23.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 15
#      12 annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
#      13 coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))
# ---> 15 bookings = pd.read_json("all_bookings27-7-23.json")
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
import datetime
import pytz
import numpy as np

group1Participants = [10,11,12,13]
group2Participants = [15,16,17,18]
group3Participants = [19,20,21]
group4Participants = [24,25,28,29,30]

annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))

bookings = pd.read_json('all_bookings27-7-23.json', lines=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 15
#      12 annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
#      13 coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))
# ---> 15 bookings = pd.read_json("all_bookings27-7-23.json", lines=True)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
import datetime
import pytz
import numpy as np

group1Participants = [10,11,12,13]
group2Participants = [15,16,17,18]
group3Participants = [19,20,21]
group4Participants = [24,25,28,29,30]

annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))

bookings = pd.read_json('all_bookings27-7-23.json', lines=True, orient='records')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 15
#      12 annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
#      13 coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))
# ---> 15 bookings = pd.read_json('all_bookings27-7-23.json', lines=True)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
import datetime
import pytz
import numpy as np

group1Participants = [10,11,12,13]
group2Participants = [15,16,17,18]
group3Participants = [19,20,21]
group4Participants = [24,25,28,29,30]

annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))

bookings = pd.read_json('all_bookings27-7-23.json', orient=str)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 15
#      12 annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
#      13 coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))
# ---> 15 bookings = pd.read_json('all_bookings27-7-23.json', lines=True, orient='records')
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
import datetime
import pytz
import numpy as np

group1Participants = [10,11,12,13]
group2Participants = [15,16,17,18]
group3Participants = [19,20,21]
group4Participants = [24,25,28,29,30]

annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))

bookings = pd.read_json('all_bookings27-7-23.json', typ="series")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 15
#      12 annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
#      13 coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))
# ---> 15 bookings = pd.read_json('all_bookings27-7-23.json', orient=str)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
import datetime
import pytz
import numpy as np

group1Participants = [10,11,12,13]
group2Participants = [15,16,17,18]
group3Participants = [19,20,21]
group4Participants = [24,25,28,29,30]

annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))

bookings = pd.read_json('all_bookings27-7-23.json', encoding = 'utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 15
#      12 annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
#      13 coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))
# ---> 15 bookings = pd.read_json('all_bookings27-7-23.json', typ="series")
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
import datetime
import pytz
import numpy as np

group1Participants = [10,11,12,13]
group2Participants = [15,16,17,18]
group3Participants = [19,20,21]
group4Participants = [24,25,28,29,30]

annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))

bookings = pd.read_json('all_bookings27-7-23.json', encoding = 'utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 15
#      12 annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
#      13 coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))
# ---> 15 bookings = pd.read_json('all_bookings27-7-23.json', encoding = 'utf-8-sig')
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
import datetime
import pytz
import numpy as np

group1Participants = [10,11,12,13]
group2Participants = [15,16,17,18]
group3Participants = [19,20,21]
group4Participants = [24,25,28,29,30]

annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))

bookings = pd.read_json("all_bookings27-7-23.json")

# %%
import pandas as pd
from matplotlib import pyplot as plt
import datetime
import pytz
import numpy as np

group1Participants = [10,11,12,13]
group2Participants = [15,16,17,18]
group3Participants = [19,20,21]
group4Participants = [24,25,28,29,30]
allGroups = group1Participants+group2Participants+group3Participants+group4Participants

annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))

bookings = pd.read_json("../ec_data/all_bookings27-7-23.json")

bookings = pd.DataFrame(bookings.fields.values.tolist())

bookings['start'] = pd.to_datetime(bookings['start'],infer_datetime_format=True)
bookings['created_at'] = pd.to_datetime(bookings['created_at'],infer_datetime_format=True)
bookings['modified_at'] = pd.to_datetime(bookings['modified_at'],infer_datetime_format=True)

bookings = bookings.loc[bookings['user'].isin(allGroups)] 
bookings = bookings.loc[bookings['start']>= coordinationStartDate ] 

bookings

pp = bookings.groupby(['user'])
ff = pp.agg({'measurement':'count'})
(ff)
# Out:
#       measurement
# user
# 10             28
# 11             32
# 12             15
# 13              8
# 15             10
# 16             61
# 17             40
# 18              4
# 19             12
# 20             11
# 21             17
# 24              8
# 25              8
# 28             12

# %%
import pandas as pd
from matplotlib import pyplot as plt
import datetime
import pytz
import numpy as np

group1Participants = [10,11,12,13]
group2Participants = [15,16,17,18]
group3Participants = [19,20,21]
group4Participants = [24,25,28,29,30]
allGroups = group1Participants+group2Participants+group3Participants+group4Participants

annotationStartDate = datetime.datetime(2023,3,30,0,0,0,0,tzinfo=pytz.timezone('UTC'))
coordinationStartDate = datetime.datetime(2023,4,21,0,0,0,0,tzinfo=pytz.timezone('UTC'))

bookings = pd.read_json("../ec_data/all_bookings27-7-23.json")

bookings = pd.DataFrame(bookings.fields.values.tolist())

bookings['start'] = pd.to_datetime(bookings['start'],infer_datetime_format=True)
bookings['created_at'] = pd.to_datetime(bookings['created_at'],infer_datetime_format=True)
bookings['modified_at'] = pd.to_datetime(bookings['modified_at'],infer_datetime_format=True)

bookings = bookings.loc[bookings['user'].isin(allGroups)] 
bookings = bookings.loc[bookings['start']>= coordinationStartDate ] 

bookings
# Out:
#                         start  duration_seconds  \
# 34  2023-04-21 08:30:00+00:00              5400
# 35  2023-04-21 17:00:00+00:00              1800
# 36  2023-04-22 14:00:00+00:00              3600
# 37  2023-04-21 13:00:00+00:00              5400
# 38  2023-04-21 15:00:00+00:00              3600
# ..                        ...               ...
# 322 2023-07-27 13:00:00+00:00              1800
# 323 2023-07-24 17:00:00+00:00              3600
# 324 2023-07-25 09:30:00+00:00              5400
# 325 2023-07-25 17:00:00+00:00              1800
# 327 2023-07-26 16:00:00+00:00              1800
#
#                                                   type  \
# 34        washing_and_drying (Lunch, plus more drying)
# 35   oven (the oven is on and also the computer and...
# 36                                          dishwasher
# 37   oven (Cooking supper for tonight but using the...
# 38   washing_and_drying (Dryer still running as wel...
# ...

# %%
pp = bookings.groupby(['user'])
ff = pp.agg({'measurement':'count'})
(ff)
# Out:
#       measurement
# user
# 10             28
# 11             32
# 12             15
# 13              8
# 15             10
# 16             61
# 17             40
# 18              4
# 19             12
# 20             11
# 21             17
# 24              8
# 25              8
# 28             12

# %%
# How far in advance was a booking made?

bookings['diff'] = (bookings['start'] - bookings['created_at']) /pd.Timedelta(minutes=1)
# pd.Timedelta(t2 - t1).seconds / 60.0

plt.rcParams.update({'font.size': 7})

# bins=[0,60*24,60*48]
bins=[0,10,30,60,120,240,60*24,60*48]
hist, bin_edges = np.histogram(bookings['diff'],bins) # make the histogram

fig,ax = plt.subplots()

# Plot the histogram heights against integers on the x axis
ax.bar(range(len(hist)),hist,width=1,edgecolor = "White") 

# Set the ticks to the middle of the bars
ax.set_xticks([i for i,j in enumerate(hist)])

# Set the xticklabels to a string that tells us what the bin edges were
ax.set_xticklabels(['{} - {}'.format(bins[i],bins[i+1]) for i,j in enumerate(hist)])

ax.set_xlabel("Minutes")
ax.set_ylabel("Frequency")

plt.show()

# %%
b = bookings['user'].isin(10)
b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 b = bookings['user'].isin(10)
#       2 b
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/series.py:5563, in Series.isin(self, values)
#    5490 def isin(self, values) -> Series:
#    5491     """
#    5492     Whether elements in Series are contained in `values`.
#    5493
#    (...)
#    5561     dtype: bool
#    5562     """
# -> 5563     result = algorithms.isin(self._values, values)
#    5564     return self._constructor(result, index=self.index).__finalize__(
#    5565         self, method="isin"
#    5566     )
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/algorithms.py:459, in isin(comps, values)
#     454     raise TypeError(
#     455         "only list-like objects are allowed to be passed "
#     456         f"to isin(), you passed a [{type(comps).__name__}]"
# ...

# %%
b = bookings[bookings["User"] == 10]
b
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'User'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
b = bookings["User"] == 10
b
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'User'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
b = bookings['user'].isin([10])
b
# Out:
# 34      True
# 35     False
# 36     False
# 37      True
# 38      True
#        ...
# 322    False
# 323    False
# 324    False
# 325    False
# 327    False
# Name: user, Length: 266, dtype: bool

# %%
user10 = bookings['user'].isin([10])
user10.head()
# Out:
# 34     True
# 35    False
# 36    False
# 37     True
# 38     True
# Name: user, dtype: bool

# %%
user10 = bookings.loc[bookings["User"] = 10]
user10
# Out:
#   Cell In[10], line 1
#     user10 = bookings.loc[bookings["User"] = 10]
#                           ^
# SyntaxError: cannot assign to subscript here. Maybe you meant '==' instead of '='?

# %%
user10 = bookings.loc[bookings["User"] == 10]
user10
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'User'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
bookings = bookings.loc[bookings['user'].isin([10])] 
bookings
# Out:
#                         start  duration_seconds  \
# 34  2023-04-21 08:30:00+00:00              5400
# 37  2023-04-21 13:00:00+00:00              5400
# 38  2023-04-21 15:00:00+00:00              3600
# 39  2023-04-22 09:00:00+00:00              5400
# 47  2023-04-24 14:00:00+00:00              7200
# 50  2023-04-25 10:15:00+00:00              5400
# 51  2023-04-25 16:00:00+00:00              3600
# 55  2023-04-27 11:00:00+00:00              7200
# 57  2023-04-28 13:00:00+00:00              5400
# 61  2023-04-29 10:00:00+00:00              3600
# 66  2023-04-29 11:00:00+00:00              7200
# 78  2023-04-30 12:00:00+00:00              3600
# 83  2023-04-30 13:00:00+00:00              1800
# 91  2023-05-01 19:00:00+00:00              1800
# 92  2023-05-02 11:00:00+00:00              7200
# 93  2023-05-02 14:00:00+00:00              5400
# 94  2023-05-02 14:00:00+00:00              5400
# 100 2023-05-03 18:00:00+00:00              1800
# ...

# %%
# How far in advance was a booking made?

bookings['diff'] = (bookings['start'] - bookings['created_at']) /pd.Timedelta(minutes=1)
# pd.Timedelta(t2 - t1).seconds / 60.0

plt.rcParams.update({'font.size': 7})

# bins=[0,60*24,60*48]
bins=[0,10,30,60,120,240,60*24,60*48]
hist, bin_edges = np.histogram(bookings['diff'],bins) # make the histogram

fig,ax = plt.subplots()

# Plot the histogram heights against integers on the x axis
ax.bar(range(len(hist)),hist,width=1,edgecolor = "White") 

# Set the ticks to the middle of the bars
ax.set_xticks([i for i,j in enumerate(hist)])

# Set the xticklabels to a string that tells us what the bin edges were
ax.set_xticklabels(['{} - {}'.format(bins[i],bins[i+1]) for i,j in enumerate(hist)])

ax.set_xlabel("Minutes")
ax.set_ylabel("Frequency")

plt.show()
# Out:
# /var/folders/8_/t19tfm1d4gj320q9vpfcj_dr0000gn/T/ipykernel_5814/1182814200.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bookings['diff'] = (bookings['start'] - bookings['created_at']) /pd.Timedelta(minutes=1)

# %%
bookings10 = bookings10.loc[bookings['user'].isin([10])] 
bookings10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 bookings10 = bookings10.loc[bookings['user'].isin([10])]
#       2 bookings10
#
# NameError: name 'bookings10' is not defined

# %%
bookings10 = bookings10.loc[bookings10['user'].isin([10])] 
bookings10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 bookings10 = bookings10.loc[bookings10['user'].isin([10])]
#       2 bookings10
#
# NameError: name 'bookings10' is not defined

# %%
bookings10 = bookings.loc[bookings['user'].isin([10])] 
bookings10
# Out:
#                         start  duration_seconds  \
# 34  2023-04-21 08:30:00+00:00              5400
# 37  2023-04-21 13:00:00+00:00              5400
# 38  2023-04-21 15:00:00+00:00              3600
# 39  2023-04-22 09:00:00+00:00              5400
# 47  2023-04-24 14:00:00+00:00              7200
# 50  2023-04-25 10:15:00+00:00              5400
# 51  2023-04-25 16:00:00+00:00              3600
# 55  2023-04-27 11:00:00+00:00              7200
# 57  2023-04-28 13:00:00+00:00              5400
# 61  2023-04-29 10:00:00+00:00              3600
# 66  2023-04-29 11:00:00+00:00              7200
# 78  2023-04-30 12:00:00+00:00              3600
# 83  2023-04-30 13:00:00+00:00              1800
# 91  2023-05-01 19:00:00+00:00              1800
# 92  2023-05-02 11:00:00+00:00              7200
# 93  2023-05-02 14:00:00+00:00              5400
# 94  2023-05-02 14:00:00+00:00              5400
# 100 2023-05-03 18:00:00+00:00              1800
# ...

# %%
bookings10['diff'] = (bookings10['start'] - bookings10['created_at']) /pd.Timedelta(minutes=1)
# pd.Timedelta(t2 - t1).seconds / 60.0

plt.rcParams.update({'font.size': 7})

# bins=[0,60*24,60*48]
bins=[0,10,30,60,120,240,60*24,60*48]
hist, bin_edges = np.histogram(bookings10['diff'],bins) # make the histogram

fig,ax = plt.subplots()

# Plot the histogram heights against integers on the x axis
ax.bar(range(len(hist)),hist,width=1,edgecolor = "White") 

# Set the ticks to the middle of the bars
ax.set_xticks([i for i,j in enumerate(hist)])

# Set the xticklabels to a string that tells us what the bin edges were
ax.set_xticklabels(['{} - {}'.format(bins[i],bins[i+1]) for i,j in enumerate(hist)])

ax.set_xlabel("Minutes")
ax.set_ylabel("Frequency")

plt.show()

# %%
pp = bookings.groupby('user')['diff']
# ff = pp.agg({'measurement':'count'})
pp.plot.hist(legend=True)


bookings['diff'].hist(by=bookings['user'],sharey=True, sharex=True,figsize=(10, 8))
# Out:
# <Axes: title={'center': '10'}>

# %%
bookings = bookings.loc[bookings['user'].isin(allGroups)] 
bookings = bookings.loc[bookings['start']>= coordinationStartDate ] 

pp = bookings.groupby('user')['diff']
# ff = pp.agg({'measurement':'count'})
pp.plot.hist(legend=True)


bookings['diff'].hist(by=bookings['user'],sharey=True, sharex=True,figsize=(10, 8))
# Out:
# <Axes: title={'center': '10'}>

# %%
bookings = pd.read_json("../ec_data/all_bookings27-7-23.json")

bookings = pd.DataFrame(bookings.fields.values.tolist())

bookings['start'] = pd.to_datetime(bookings['start'],infer_datetime_format=True)
bookings['created_at'] = pd.to_datetime(bookings['created_at'],infer_datetime_format=True)
bookings['modified_at'] = pd.to_datetime(bookings['modified_at'],infer_datetime_format=True)

bookings = bookings.loc[bookings['user'].isin(allGroups)] 
bookings = bookings.loc[bookings['start']>= coordinationStartDate ] 

bookings
# Out:
#                         start  duration_seconds  \
# 34  2023-04-21 08:30:00+00:00              5400
# 35  2023-04-21 17:00:00+00:00              1800
# 36  2023-04-22 14:00:00+00:00              3600
# 37  2023-04-21 13:00:00+00:00              5400
# 38  2023-04-21 15:00:00+00:00              3600
# ..                        ...               ...
# 322 2023-07-27 13:00:00+00:00              1800
# 323 2023-07-24 17:00:00+00:00              3600
# 324 2023-07-25 09:30:00+00:00              5400
# 325 2023-07-25 17:00:00+00:00              1800
# 327 2023-07-26 16:00:00+00:00              1800
#
#                                                   type  \
# 34        washing_and_drying (Lunch, plus more drying)
# 35   oven (the oven is on and also the computer and...
# 36                                          dishwasher
# 37   oven (Cooking supper for tonight but using the...
# 38   washing_and_drying (Dryer still running as wel...
# ...

# %%
pp = bookings.groupby('user')['diff']
# ff = pp.agg({'measurement':'count'})
pp.plot.hist(legend=True)


bookings['diff'].hist(by=bookings['user'],sharey=True, sharex=True,figsize=(10, 8))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 pp = bookings.groupby('user')['diff']
#       2 # ff = pp.agg({'measurement':'count'})
#       3 pp.plot.hist(legend=True)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/groupby/generic.py:1416, in DataFrameGroupBy.__getitem__(self, key)
#    1407 if isinstance(key, tuple) and len(key) > 1:
#    1408     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1409     # valid syntax, so don't raise warning
#    1410     warnings.warn(
#    1411         "Indexing with multiple keys (implicitly converted to a tuple "
#    1412         "of keys) will be deprecated, use a list instead.",
#    1413         FutureWarning,
#    1414         stacklevel=find_stack_level(),
#    1415     )
# -> 1416 return super().__getitem__(key)
#
# ...

# %%
bookings['diff'] = (bookings['start'] - bookings['created_at']) /pd.Timedelta(minutes=1)
# pd.Timedelta(t2 - t1).seconds / 60.0

plt.rcParams.update({'font.size': 7})

# bins=[0,60*24,60*48]
bins=[0,10,30,60,120,240,60*24,60*48]
hist, bin_edges = np.histogram(bookings['diff'],bins) # make the histogram

fig,ax = plt.subplots()

# Plot the histogram heights against integers on the x axis
ax.bar(range(len(hist)),hist,width=1,edgecolor = "White") 

# Set the ticks to the middle of the bars
ax.set_xticks([i for i,j in enumerate(hist)])

# Set the xticklabels to a string that tells us what the bin edges were
ax.set_xticklabels(['{} - {}'.format(bins[i],bins[i+1]) for i,j in enumerate(hist)])

ax.set_xlabel("Minutes")
ax.set_ylabel("Frequency")

plt.show()

# %%
pp = bookings.groupby('user')['diff']
# ff = pp.agg({'measurement':'count'})
pp.plot.hist(legend=True)


bookings['diff'].hist(by=bookings['user'],sharey=True, sharex=True,figsize=(10, 8))
# Out:
# array([[<Axes: title={'center': '10'}>, <Axes: title={'center': '11'}>,
#         <Axes: title={'center': '12'}>, <Axes: title={'center': '13'}>],
#        [<Axes: title={'center': '15'}>, <Axes: title={'center': '16'}>,
#         <Axes: title={'center': '17'}>, <Axes: title={'center': '18'}>],
#        [<Axes: title={'center': '19'}>, <Axes: title={'center': '20'}>,
#         <Axes: title={'center': '21'}>, <Axes: title={'center': '24'}>],
#        [<Axes: title={'center': '25'}>, <Axes: title={'center': '28'}>,
#         <Axes: >, <Axes: >]], dtype=object)
